# %% [markdown]
# ## Install required packages

# %%
# !conda install -y -c anaconda pandas
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/yanboyang713/.conda/envs/anomaly
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB  anaconda
#     bottleneck-1.3.5           |   py37h7deecbd_0         125 KB  anaconda
#     ca-certificates-2023.01.10 |       h06a4308_0         127 KB  anaconda
#     certifi-2022.12.7          |   py37h06a4308_0         152 KB  anaconda
#     intel-openmp-2021.4.0      |    h06a4308_3561         8.8 MB  anaconda
#     mkl-2021.4.0               |     h06a4308_640       219.1 MB  anaconda
#     mkl-service-2.4.0          |   py37h7f8727e_0          59 KB  anaconda
#     mkl_fft-1.3.1              |   py37hd3c417c_0         190 KB  anaconda
#     mkl_random-1.2.2           |   py37h51133e4_0         332 KB  anaconda
#     numexpr-2.8.4              |   py37he184ba9_0         133 KB  anaconda
#     numpy-1.21.5               |   py37h6c91a56_3          10 KB  anaconda
#     numpy-base-1.21.5          |   py37ha15fc14_3         6.1 MB  anaconda
#     openssl-1.1.1s             |       h7f8727e_0         3.8 MB  anaconda
#     pandas-1.3.5               |   py37h8c16a72_0        11.9 MB  anaconda
#     pytz-2022.7                |   py37h06a4308_0         254 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:       251.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               anaconda/linux-64::blas-1.0-mkl
#   bottleneck         anaconda/linux-64::bottleneck-1.3.5-py37h7deecbd_0
#   intel-openmp       anaconda/linux-64::intel-openmp-2021.4.0-h06a4308_3561
#   mkl                anaconda/linux-64::mkl-2021.4.0-h06a4308_640
#   mkl-service        anaconda/linux-64::mkl-service-2.4.0-py37h7f8727e_0
#   mkl_fft            anaconda/linux-64::mkl_fft-1.3.1-py37hd3c417c_0
#   mkl_random         anaconda/linux-64::mkl_random-1.2.2-py37h51133e4_0
#   numexpr            anaconda/linux-64::numexpr-2.8.4-py37he184ba9_0
#   numpy              anaconda/linux-64::numpy-1.21.5-py37h6c91a56_3
#   numpy-base         anaconda/linux-64::numpy-base-1.21.5-py37ha15fc14_3
#   pandas             anaconda/linux-64::pandas-1.3.5-py37h8c16a72_0
#   pytz               anaconda/linux-64::pytz-2022.7-py37h06a4308_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates                                 pkgs/main --> anaconda
#   certifi                                         pkgs/main --> anaconda
#   openssl              pkgs/main::openssl-1.1.1t-h7f8727e_0 --> anaconda::openssl-1.1.1s-h7f8727e_0
#
#
#
# Downloading and Extracting Packages
# openssl-1.1.1s       | 3.8 MB    |                                       |   0%
# ca-certificates-2023 | 127 KB    |                                       |   0%
#
# numexpr-2.8.4        | 133 KB    |                                       |   0%
#
#
# pytz-2022.7          | 254 KB    |                                       |   0%
#
#
#
# bottleneck-1.3.5     | 125 KB    |                                       |   0%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    |                                       |   0%
#
#
#
#
#
# mkl_random-1.2.2     | 332 KB    |                                       |   0%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    |                                       |   0%
#
#
#
#
#
#
#
# mkl_fft-1.3.1        | 190 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# numpy-1.21.5         | 10 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# blas-1.0             | 6 KB      |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# certifi-2022.12.7    | 152 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-service-2.4.0    | 59 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  |                                       |   0%
# ca-certificates-2023 | 127 KB    | ####6                                 |  13%
#
#
# pytz-2022.7          | 254 KB    | ##3                                   |   6%
#
# numexpr-2.8.4        | 133 KB    | ####4                                 |  12%
# ca-certificates-2023 | 127 KB    | ##################################### | 100%
# ca-certificates-2023 | 127 KB    | ##################################### | 100%
#
#
# pytz-2022.7          | 254 KB    | ##################6                   |  50%
#
# numexpr-2.8.4        | 133 KB    | ###################################6  |  96%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    |                                       |   0%
#
# numexpr-2.8.4        | 133 KB    | ##################################### | 100%
#
#
#
#
#
# mkl_random-1.2.2     | 332 KB    | #7                                    |   5%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    |                                       |   0%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | 9                                     |   3%
#
#
#
#
#
# mkl_random-1.2.2     | 332 KB    | #######1                              |  19%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | 9                                     |   3%
#
#
#
#
#
# mkl_random-1.2.2     | 332 KB    | ##########################7           |  72%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ##2                                   |   6%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | #4                                    |   4%
#
#
# pytz-2022.7          | 254 KB    | ##################################### | 100%
#
#
# pytz-2022.7          | 254 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# mkl_fft-1.3.1        | 190 KB    | ###1                                  |   8%
#
#
#
#
#
# mkl_random-1.2.2     | 332 KB    | ##################################### | 100%
#
#
#
#
#
# mkl_random-1.2.2     | 332 KB    | ##################################### | 100%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ###                                   |   8%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | #9                                    |   5%
#
#
#
#
#
#
#
# mkl_fft-1.3.1        | 190 KB    | ###############5                      |  42%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ####3                                 |  12%
#
#
#
#
#
#
#
# mkl_fft-1.3.1        | 190 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# numpy-1.21.5         | 10 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# numpy-1.21.5         | 10 KB     | ##################################### | 100%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | ###8                                  |  11%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | #####4                                |  15%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   |                                       |   0%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | ####8                                 |  13%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ######3                               |  17%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | 4                                     |   1%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | #####8                                |  16%
# intel-openmp-2021.4. | 8.8 MB    | #######3                              |  20%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | 9                                     |   3%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | ######8                               |  18%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ########2                             |  22%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | #3                                    |   4%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | #########8                            |  27%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | ########6                             |  23%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ##1                                   |   6%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ##6                                   |   7%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ##########8                           |  29%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | #########7                            |  26%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ###1                                  |   9%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | ##########8                           |  29%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ###########8                          |  32%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ###7                                  |  10%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | ###########9                          |  32%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | #############1                        |  36%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ####2                                 |  12%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | ############9                         |  35%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ##############                        |  38%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | #####4                                |  15%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ###############6                      |  42%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | ##############9                       |  40%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | ################                      |  43%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ################3                     |  44%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ######                                |  16%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | #################7                    |  48%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ######9                               |  19%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | #################7                    |  48%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | ##################8                   |  51%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ##################6                   |  50%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | #######5                              |  20%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ###################5                  |  53%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ########1                             |  22%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | ####################                  |  54%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ####################3                 |  55%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | #########2                            |  25%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | #####################7                |  59%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | #####################1                |  57%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | #########8                            |  27%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | #####################8                |  59%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | ######################8               |  62%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ##########5                           |  28%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ######################6               |  61%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | #######################8              |  65%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ###########                           |  30%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | #######################4              |  63%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | ########################8             |  67%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ########################              |  65%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ###########5                          |  31%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ########################6             |  67%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | #########################7            |  69%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ############4                         |  34%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | ###########################1          |  73%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ##########################            |  71%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | #############1                        |  35%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ##########################9           |  73%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | ############################          |  76%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | #############7                        |  37%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | #############################         |  78%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ###########################7          |  75%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ##############2                       |  39%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ############################5         |  77%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | #############################9        |  81%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ##############8                       |  40%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | #############################4        |  80%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | ###############################       |  84%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ###############5                      |  42%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | ###############################9      |  86%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ##############################2       |  82%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ################                      |  43%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ###############################3      |  85%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ################7                     |  45%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | #################################     |  89%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | #################2                    |  47%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | ##################################    |  92%
# intel-openmp-2021.4. | 8.8 MB    | ################################1     |  87%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | #################8                    |  48%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | ##################################9   |  94%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ################################9     |  89%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | ###################################7  |  97%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ##################4                   |  50%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | #################################7    |  91%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | ####################################9 | 100%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ##################9                   |  51%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ###################################4  |  96%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ####################                  |  54%
#
#
#
#
#
#
#
#
#
#
# blas-1.0             | 6 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# blas-1.0             | 6 KB      | ##################################### | 100%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ####################################3 |  98%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ####################7                 |  56%
#
#
#
#
#
#
#
#
#
#
#
# certifi-2022.12.7    | 152 KB    | ###9                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-service-2.4.0    | 59 KB     | #########9                            |  27%
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1s       | 3.8 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | #####################4                |  58%
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-service-2.4.0    | 59 KB     | ##################################### | 100%
#
#
#
# bottleneck-1.3.5     | 125 KB    | ####7                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  |                                       |   0%
#
#
#
#
#
#
#
#
#
# openssl-1.1.1s       | 3.8 MB    | #2                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
# certifi-2022.12.7    | 152 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# certifi-2022.12.7    | 152 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  |                                       |   0%
#
#
#
# openssl-1.1.1s       | 3.8 MB    | #9                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1s       | 3.8 MB    | ##5                                   |   7%
#
#
#
#
#
#
#
#
#
# openssl-1.1.1s       | 3.8 MB    | ####8                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 1                                     |   0%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ########################3             |  66%
#
#
#
# openssl-1.1.1s       | 3.8 MB    | #######2                              |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 1                                     |   0%
#
#
#
#
#
#
#
#
#
# openssl-1.1.1s       | 3.8 MB    | ###########8                          |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 1                                     |   0%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | #########################8            |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1s       | 3.8 MB    | ##################                    |  49%
#
#
#
#
#
#
#
#
#
# openssl-1.1.1s       | 3.8 MB    | #####################1                |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 2                                     |   1%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ###########################           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1s       | 3.8 MB    | ########################1             |  65%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ############################          |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1s       | 3.8 MB    | #############################7        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 3                                     |   1%
#
#
#
#
#
#
#
#
#
# openssl-1.1.1s       | 3.8 MB    | ###################################8  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 3                                     |   1%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | #############################3        |  79%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | #############################9        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 4                                     |   1%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ##############################5       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 4                                     |   1%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ###############################2      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 4                                     |   1%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ################################      |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 5                                     |   1%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ################################7     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 5                                     |   2%
#
#
#
#
#
#
# numpy-base-1.21.5    | 6.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | #################################5    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 6                                     |   2%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ##################################5   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 6                                     |   2%
#
#
#
#
# intel-openmp-2021.4. | 8.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ###################################4  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 6                                     |   2%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ####################################2 |  98%
# mkl-2021.4.0         | 219.1 MB  | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1s       | 3.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 9                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 9                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #2                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #3                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #5                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #6                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #6                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #7                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #8                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #9                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##                                    |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##1                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##2                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##3                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##4                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##6                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##7                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##8                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###1                                  |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###2                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###3                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###4                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###5                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###6                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###8                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###9                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####1                                 |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####2                                 |  12%
#
#
#
#
#
#
#
#
#
# pandas-1.3.5         | 11.9 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####3                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####4                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####5                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####6                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####8                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #####                                 |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #####1                                |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #####3                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #####4                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #####6                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #####7                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #####8                                |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #####9                                |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ######                                |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ######1                               |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ######2                               |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ######3                               |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ######4                               |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ######5                               |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ######6                               |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ######7                               |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ######9                               |  19%
# mkl-2021.4.0         | 219.1 MB  | #######                               |  19%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #######1                              |  19%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #######2                              |  19%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #######3                              |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #######4                              |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #######5                              |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #######6                              |  21%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #######8                              |  21%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #######9                              |  21%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########                              |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########1                             |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########2                             |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########2                             |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########5                             |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########6                             |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########7                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########8                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########9                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########9                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #########                             |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #########1                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #########2                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #########3                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #########4                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #########5                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #########6                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #########7                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #########9                            |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##########                            |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##########1                           |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##########2                           |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##########3                           |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##########4                           |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##########5                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##########6                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##########6                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##########7                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##########9                           |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###########                           |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###########1                          |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###########2                          |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###########2                          |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###########3                          |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###########4                          |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###########5                          |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###########5                          |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###########7                          |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###########8                          |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###########9                          |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ############                          |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ############1                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ############2                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ############3                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ############4                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ############5                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ############6                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ############7                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ############8                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ############9                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #############1                        |  35%
# mkl-2021.4.0         | 219.1 MB  | #############2                        |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #############3                        |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #############4                        |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #############4                        |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #############5                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #############6                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #############7                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #############8                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #############9                        |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##############                        |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##############1                       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##############2                       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##############2                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##############3                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##############4                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##############5                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##############5                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##############6                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##############7                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##############7                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##############8                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##############9                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###############                       |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###############                       |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###############1                      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###############1                      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###############2                      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###############3                      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###############4                      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###############4                      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###############5                      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###############6                      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###############7                      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###############8                      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###############8                      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###############9                      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ################                      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ################1                     |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ################1                     |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ################2                     |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ################3                     |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ################5                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ################6                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ################7                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ################8                     |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ################9                     |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #################                     |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #################1                    |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #################2                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #################2                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #################4                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #################5                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #################6                    |  48%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #################7                    |  48%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #################9                    |  48%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##################                    |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##################1                   |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##################2                   |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##################2                   |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##################4                   |  50%
# mkl-2021.4.0         | 219.1 MB  | ##################5                   |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##################6                   |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##################7                   |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##################8                   |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##################9                   |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###################                   |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###################1                  |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###################2                  |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###################3                  |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###################4                  |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###################5                  |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###################6                  |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###################8                  |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###################9                  |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####################                  |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####################1                 |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####################2                 |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####################3                 |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####################4                 |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####################5                 |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####################6                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####################7                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####################8                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####################9                 |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #####################                 |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #####################1                |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #####################2                |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #####################4                |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #####################5                |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #####################6                |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #####################7                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #####################9                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ######################                |  60%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ######################1               |  60%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ######################2               |  60%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ######################4               |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ######################4               |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ######################6               |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ######################7               |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ######################9               |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #######################               |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #######################1              |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #######################2              |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #######################4              |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #######################5              |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #######################6              |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #######################7              |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #######################8              |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #######################9              |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########################              |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########################1             |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########################2             |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########################2             |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########################4             |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########################5             |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########################6             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########################7             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########################8             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########################9             |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #########################             |  68%
# mkl-2021.4.0         | 219.1 MB  | #########################1            |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #########################3            |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #########################4            |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #########################6            |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #########################7            |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #########################8            |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #########################9            |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##########################            |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##########################1           |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##########################3           |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##########################4           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##########################5           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##########################7           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##########################8           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##########################9           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###########################           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###########################1          |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###########################2          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###########################3          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###########################4          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###########################5          |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###########################6          |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###########################7          |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###########################8          |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###########################9          |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ############################          |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ############################1         |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ############################2         |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ############################3         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ############################4         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ############################6         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ############################7         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ############################8         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ############################9         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #############################         |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #############################2        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #############################3        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #############################4        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #############################6        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #############################7        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #############################8        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##############################        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##############################1       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##############################3       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##############################4       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##############################5       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##############################6       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##############################7       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##############################9       |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###############################       |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###############################1      |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###############################2      |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###############################3      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###############################4      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###############################5      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###############################6      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###############################8      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###############################9      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ################################      |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ################################1     |  87%
# mkl-2021.4.0         | 219.1 MB  | ################################3     |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ################################4     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ################################5     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ################################6     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ################################8     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ################################9     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #################################     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #################################1    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #################################3    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #################################4    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #################################5    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #################################6    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #################################7    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #################################8    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #################################9    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##################################    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##################################    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##################################2   |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##################################3   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##################################4   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##################################6   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##################################7   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##################################8   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##################################9   |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###################################   |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###################################1  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###################################3  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###################################4  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###################################5  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###################################6  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###################################8  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###################################9  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####################################  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####################################1 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####################################2 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####################################3 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####################################4 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####################################5 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####################################6 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####################################7 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####################################8 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####################################9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda install -y -c anaconda openpyxl
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/yanboyang713/.conda/envs/anomaly
#
#   added / updated specs:
#     - openpyxl
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     et_xmlfile-1.1.0           |   py37h06a4308_0           9 KB  anaconda
#     openpyxl-3.0.10            |   py37h5eee18b_0         551 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         560 KB
#
# The following NEW packages will be INSTALLED:
#
#   et_xmlfile         anaconda/linux-64::et_xmlfile-1.1.0-py37h06a4308_0
#   openpyxl           anaconda/linux-64::openpyxl-3.0.10-py37h5eee18b_0
#
#
#
# Downloading and Extracting Packages
# et_xmlfile-1.1.0     | 9 KB      |                                       |   0%
# openpyxl-3.0.10      | 551 KB    |                                       |   0%
# et_xmlfile-1.1.0     | 9 KB      | ##################################### | 100%
# openpyxl-3.0.10      | 551 KB    | #####################4                |  58%
# openpyxl-3.0.10      | 551 KB    | ##################################### | 100%
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda install -y -c conda-forge matplotlib
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/yanboyang713/.conda/envs/anomaly
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.12.7  |       ha878542_0         143 KB  conda-forge
#     certifi-2022.12.7          |     pyhd8ed1ab_0         147 KB  conda-forge
#     cycler-0.11.0              |     pyhd8ed1ab_0          10 KB  conda-forge
#     freetype-2.10.4            |       h0708190_1         890 KB  conda-forge
#     icu-67.1                   |       he1b5a44_0        12.9 MB  conda-forge
#     kiwisolver-1.4.4           |   py37h6a678d5_0          74 KB
#     libpng-1.6.39              |       h5eee18b_0         304 KB
#     matplotlib-3.2.2           |                1           6 KB  conda-forge
#     matplotlib-base-3.2.2      |   py37h1d35a4c_1         7.0 MB  conda-forge
#     nbconvert-6.4.5            |   py37h89c1867_0         556 KB  conda-forge
#     openssl-1.1.1l             |       h7f98852_0         2.1 MB  conda-forge
#     pandoc-2.19.2              |       ha770c72_0        12.8 MB  conda-forge
#     pyparsing-3.0.9            |     pyhd8ed1ab_0          79 KB  conda-forge
#     python_abi-3.7             |          2_cp37m           4 KB  conda-forge
#     testpath-0.6.0             |     pyhd8ed1ab_0          85 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        37.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   cycler             conda-forge/noarch::cycler-0.11.0-pyhd8ed1ab_0
#   freetype           conda-forge/linux-64::freetype-2.10.4-h0708190_1
#   kiwisolver         pkgs/main/linux-64::kiwisolver-1.4.4-py37h6a678d5_0
#   libpng             pkgs/main/linux-64::libpng-1.6.39-h5eee18b_0
#   matplotlib         conda-forge/linux-64::matplotlib-3.2.2-1
#   matplotlib-base    conda-forge/linux-64::matplotlib-base-3.2.2-py37h1d35a4c_1
#   pandoc             conda-forge/linux-64::pandoc-2.19.2-ha770c72_0
#   pyparsing          conda-forge/noarch::pyparsing-3.0.9-pyhd8ed1ab_0
#   python_abi         conda-forge/linux-64::python_abi-3.7-2_cp37m
#   testpath           conda-forge/noarch::testpath-0.6.0-pyhd8ed1ab_0
#
# The following packages will be REMOVED:
#
#   libxml2-2.9.14-h74e7548_0
#   libxslt-1.1.35-h4e12654_0
#   lxml-4.9.1-py37h1edc446_0
#
# The following packages will be UPDATED:
#
#   icu                        pkgs/main::icu-58.2-he6710b0_3 --> conda-forge::icu-67.1-he1b5a44_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    anaconda::ca-certificates-2023.01.10-~ --> conda-forge::ca-certificates-2022.12.7-ha878542_0
#   certifi            anaconda/linux-64::certifi-2022.12.7-~ --> conda-forge/noarch::certifi-2022.12.7-pyhd8ed1ab_0
#   nbconvert          pkgs/main::nbconvert-6.5.4-py37h06a43~ --> conda-forge::nbconvert-6.4.5-py37h89c1867_0
#   openssl               anaconda::openssl-1.1.1s-h7f8727e_0 --> conda-forge::openssl-1.1.1l-h7f98852_0
#
#
#
# Downloading and Extracting Packages
# testpath-0.6.0       | 85 KB     |                                       |   0%
# certifi-2022.12.7    | 147 KB    |                                       |   0%
#
# matplotlib-base-3.2. | 7.0 MB    |                                       |   0%
#
#
# matplotlib-3.2.2     | 6 KB      |                                       |   0%
#
#
#
# python_abi-3.7       | 4 KB      |                                       |   0%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   |                                       |   0%
#
#
#
#
#
# pyparsing-3.0.9      | 79 KB     |                                       |   0%
#
#
#
#
#
#
# freetype-2.10.4      | 890 KB    |                                       |   0%
#
#
#
#
#
#
#
# nbconvert-6.4.5      | 556 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# kiwisolver-1.4.4     | 74 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
# openssl-1.1.1l       | 2.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# cycler-0.11.0        | 10 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2022 | 143 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libpng-1.6.39        | 304 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# testpath-0.6.0       | 85 KB     | ######9                               |  19%
#
#
#
# python_abi-3.7       | 4 KB      | ##################################### | 100%
#
#
# matplotlib-3.2.2     | 6 KB      | ##################################### | 100%
# certifi-2022.12.7    | 147 KB    | ####                                  |  11%
#
# matplotlib-base-3.2. | 7.0 MB    |                                       |   0%
#
#
#
# python_abi-3.7       | 4 KB      | ##################################### | 100%
#
#
# matplotlib-3.2.2     | 6 KB      | ##################################### | 100%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   |                                       |   0%
#
#
#
#
#
# testpath-0.6.0       | 85 KB     | ##################################### | 100%
# certifi-2022.12.7    | 147 KB    | ##################################### | 100%
# certifi-2022.12.7    | 147 KB    | ##################################### | 100%
#
# matplotlib-base-3.2. | 7.0 MB    | 9                                     |   2%
#
#
#
#
#
#
# freetype-2.10.4      | 890 KB    | 6                                     |   2%
#
#
#
#
#
# pyparsing-3.0.9      | 79 KB     | ##################################### | 100%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | 3                                     |   1%
#
#
#
#
#
#
#
# nbconvert-6.4.5      | 556 KB    | #                                     |   3%
#
# matplotlib-base-3.2. | 7.0 MB    | #8                                    |   5%
#
#
#
#
#
#
# freetype-2.10.4      | 890 KB    | #####3                                |  14%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | 5                                     |   1%
#
#
#
#
#
#
#
# nbconvert-6.4.5      | 556 KB    | #########5                            |  26%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | 7                                     |   2%
#
#
#
#
#
#
# freetype-2.10.4      | 890 KB    | #########3                            |  25%
#
# matplotlib-base-3.2. | 7.0 MB    | ##4                                   |   7%
#
#
#
#
#
#
#
# nbconvert-6.4.5      | 556 KB    | #################                     |  46%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | #                                     |   3%
#
# matplotlib-base-3.2. | 7.0 MB    | ###8                                  |  10%
#
#
#
#
#
#
# freetype-2.10.4      | 890 KB    | #####################2                |  58%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | #3                                    |   4%
#
# matplotlib-base-3.2. | 7.0 MB    | ####6                                 |  13%
#
#
#
#
#
#
# freetype-2.10.4      | 890 KB    | ###########################2          |  74%
#
#
#
#
#
#
#
#
#
# openssl-1.1.1l       | 2.1 MB    | 2                                     |   1%
#
#
#
#
#
#
#
#
#
# openssl-1.1.1l       | 2.1 MB    | #8                                    |   5%
#
#
#
#
#
#
#
# nbconvert-6.4.5      | 556 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# nbconvert-6.4.5      | 556 KB    | ##################################### | 100%
#
#
#
#
#
#
# freetype-2.10.4      | 890 KB    | #################################2    |  90%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | #6                                    |   4%
#
# matplotlib-base-3.2. | 7.0 MB    | #####4                                |  15%
# kiwisolver-1.4.4     | 74 KB     | ########                              |  22%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | #8                                    |   5%
#
# matplotlib-base-3.2. | 7.0 MB    | ######1                               |  17%
#
#
#
#
#
#
#
#
#
# openssl-1.1.1l       | 2.1 MB    | ##9                                   |   8%
#
#
#
#
#
#
#
#
# kiwisolver-1.4.4     | 74 KB     | ################################1     |  87%
#
#
#
#
#
#
#
#
# kiwisolver-1.4.4     | 74 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# cycler-0.11.0        | 10 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2022 | 143 KB    | ####1                                 |  11%
#
#
#
#
#
#
#
#
#
#
# cycler-0.11.0        | 10 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# openssl-1.1.1l       | 2.1 MB    | ######7                               |  18%
#
# matplotlib-base-3.2. | 7.0 MB    | #######6                              |  21%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ##2                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2022 | 143 KB    | #################################2    |  90%
#
#
#
#
#
#
# freetype-2.10.4      | 890 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2022 | 143 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# openssl-1.1.1l       | 2.1 MB    | ############7                         |  34%
#
# matplotlib-base-3.2. | 7.0 MB    | #########7                            |  26%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ##9                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
# openssl-1.1.1l       | 2.1 MB    | ################5                     |  45%
#
# matplotlib-base-3.2. | 7.0 MB    | ##########9                           |  29%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ###3                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
# libpng-1.6.39        | 304 KB    | #9                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | 4                                     |   1%
#
#
#
#
#
#
#
#
#
# openssl-1.1.1l       | 2.1 MB    | ###################8                  |  54%
#
# matplotlib-base-3.2. | 7.0 MB    | ############                          |  33%
#
#
#
#
#
#
#
#
#
#
#
#
# libpng-1.6.39        | 304 KB    | #######7                              |  21%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ###6                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
# libpng-1.6.39        | 304 KB    | #############6                        |  37%
#
#
#
#
#
#
#
#
#
# openssl-1.1.1l       | 2.1 MB    | ######################7               |  62%
#
# matplotlib-base-3.2. | 7.0 MB    | #############1                        |  35%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ####                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
#
# libpng-1.6.39        | 304 KB    | ###########################2          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | 9                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
# libpng-1.6.39        | 304 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# openssl-1.1.1l       | 2.1 MB    | ############################2         |  76%
#
# matplotlib-base-3.2. | 7.0 MB    | ##############6                       |  40%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ####4                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | #5                                    |   4%
#
#
#
#
#
#
#
#
#
# openssl-1.1.1l       | 2.1 MB    | ###############################4      |  85%
#
# matplotlib-base-3.2. | 7.0 MB    | ###############7                      |  43%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ####7                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | #8                                    |   5%
#
#
#
#
#
#
#
#
#
# openssl-1.1.1l       | 2.1 MB    | ##################################7   |  94%
#
# matplotlib-base-3.2. | 7.0 MB    | ################8                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ##2                                   |   6%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | #####1                                |  14%
#
# matplotlib-base-3.2. | 7.0 MB    | #################8                    |  48%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ##7                                   |   7%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | #####8                                |  16%
#
# matplotlib-base-3.2. | 7.0 MB    | ###################2                  |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ###1                                  |   8%
#
# matplotlib-base-3.2. | 7.0 MB    | ####################3                 |  55%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ######2                               |  17%
#
# matplotlib-base-3.2. | 7.0 MB    | #####################5                |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ###4                                  |   9%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ######6                               |  18%
#
#
#
#
#
#
#
#
#
# openssl-1.1.1l       | 2.1 MB    | ##################################### | 100%
#
# matplotlib-base-3.2. | 7.0 MB    | ######################7               |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ###8                                  |  10%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | #######                               |  19%
#
# matplotlib-base-3.2. | 7.0 MB    | ########################1             |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ####2                                 |  11%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | #######5                              |  20%
#
# matplotlib-base-3.2. | 7.0 MB    | #########################4            |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ####5                                 |  12%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | #######9                              |  21%
#
# matplotlib-base-3.2. | 7.0 MB    | ##########################9           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ####9                                 |  13%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ########3                             |  23%
#
# matplotlib-base-3.2. | 7.0 MB    | ############################7         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | #####3                                |  14%
# pandoc-2.19.2        | 12.8 MB   | ########8                             |  24%
#
# matplotlib-base-3.2. | 7.0 MB    | ##############################2       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | #####7                                |  15%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | #########2                            |  25%
#
# matplotlib-base-3.2. | 7.0 MB    | ###############################6      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ######1                               |  17%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | #########6                            |  26%
#
# matplotlib-base-3.2. | 7.0 MB    | #################################1    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ######5                               |  18%
#
# matplotlib-base-3.2. | 7.0 MB    | ###################################5  |  96%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ##########4                           |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ######9                               |  19%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ##########9                           |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | #######4                              |  20%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ###########6                          |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | #######8                              |  21%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ############1                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ########3                             |  23%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ############7                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ########8                             |  24%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | #############4                        |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | #########3                            |  25%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ##############1                       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | #########8                            |  27%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ##############8                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ##########4                           |  28%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ###############6                      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ##########9                           |  30%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ################4                     |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ###########4                          |  31%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | #################2                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ############                          |  32%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ##################2                   |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ############5                         |  34%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ###################1                  |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | #############1                        |  36%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ####################                  |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | #############7                        |  37%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ####################9                 |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ##############3                       |  39%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ######################                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ###############                       |  41%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | #######################               |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ###############6                      |  42%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ########################              |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ################2                     |  44%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | #########################             |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ################9                     |  46%
#
# matplotlib-base-3.2. | 7.0 MB    | ##################################### | 100%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ##########################            |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | #################6                    |  48%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ###########################           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ##################3                   |  49%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ############################          |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ##################8                   |  51%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | #############################5        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ###################7                  |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ####################4                 |  55%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ##############################6       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | #####################                 |  57%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ###############################5      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | #####################7                |  59%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ################################5     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ######################3               |  60%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | #################################5    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ######################9               |  62%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ##################################6   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | #######################6              |  64%
#
#
#
#
# pandoc-2.19.2        | 12.8 MB   | ###################################5  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ########################2             |  65%
# pandoc-2.19.2        | 12.8 MB   | ####################################4 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ########################9             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | #########################7            |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ##########################5           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ###########################5          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ############################5         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | #############################6        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ##############################5       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ################################2     |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | #################################6    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ###################################2  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ####################################8 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-67.1             | 12.9 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda install -y -c anaconda seaborn
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/yanboyang713/.conda/envs/anomaly
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     seaborn-0.12.2             |   py37h06a4308_0         487 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         487 KB
#
# The following NEW packages will be INSTALLED:
#
#   seaborn            anaconda/linux-64::seaborn-0.12.2-py37h06a4308_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2022.12.~ --> anaconda::ca-certificates-2023.01.10-h06a4308_0
#   openssl            conda-forge::openssl-1.1.1l-h7f98852_0 --> anaconda::openssl-1.1.1s-h7f8727e_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge/noarch::certifi-2022.12.7~ --> anaconda/linux-64::certifi-2022.12.7-py37h06a4308_0
#
#
#
# Downloading and Extracting Packages
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda install -y -c menpo opencv
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: /
# Warning: 4 possible package resolutions (only showing differing packages):
#   - anaconda/linux-64::ca-certificates-2023.01.10-h06a4308_0, anaconda/linux-64::certifi-2022.12.7-py37h06a4308_0
#   - anaconda/linux-64::ca-certificates-2023.01.10-h06a4308_0, defaults/linux-64::certifi-2022.12.7-py37h06a4308_0
#   - anaconda/linux-64::certifi-2022.12.7-py37h06a4308_0, defaults/linux-64::ca-certificates-2023.01.10-h06a4308_0
#   - defaults/linux-64::ca-certificates-2023.01.10-h06a4308_0, defaults/linux-64::certifi-2022.12.7-py37h06a4308done
#
# ## Package Plan ##
#
#   environment location: /home/yanboyang713/.conda/envs/anomaly
#
#   added / updated specs:
#     - opencv
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cairo-1.16.0               |       hb05425b_3         1.2 MB
#     expat-2.4.9                |       h6a678d5_0         156 KB
#     ffmpeg-4.0                 |       hcdf2ecd_0        53.3 MB
#     fontconfig-2.14.1          |       h52c9d5c_1         281 KB
#     freeglut-3.0.0             |       hf484d3e_5         176 KB
#     glib-2.69.1                |       h4ff587b_1         1.7 MB
#     graphite2-1.3.14           |       h295c915_1          97 KB
#     harfbuzz-1.8.8             |       hffaf4a1_0         507 KB
#     hdf5-1.10.2                |       hba1933b_1         3.8 MB
#     jasper-2.0.14              |       hd8c5072_2         736 KB
#     jpeg-9e                    |       h5eee18b_1         262 KB
#     lerc-3.0                   |       h295c915_0         196 KB
#     libdeflate-1.17            |       h5eee18b_0          69 KB
#     libgfortran-ng-7.5.0       |      ha8ba4b0_17          22 KB
#     libgfortran4-7.5.0         |      ha8ba4b0_17         995 KB
#     libglu-9.0.0               |       hf484d3e_1         271 KB
#     libopencv-3.4.2            |       hb342d67_1        21.8 MB
#     libopus-1.3.1              |       h7b6447c_0         491 KB
#     libtiff-4.5.0              |       h6a678d5_2         479 KB
#     libvpx-1.7.0               |       h439df22_0         1.2 MB
#     libwebp-base-1.2.4         |       h5eee18b_1         376 KB
#     libxcb-1.15                |       h7f8727e_0         505 KB
#     lz4-c-1.9.4                |       h6a678d5_0         154 KB
#     matplotlib-base-3.2.2      |   py37hef1b27d_0         5.4 MB
#     opencv-3.4.2               |   py37h6fd60c2_1          11 KB
#     pcre-8.45                  |       h295c915_0         207 KB
#     pixman-0.40.0              |       h7f8727e_1         373 KB
#     py-opencv-3.4.2            |   py37hb342d67_1         1.0 MB
#     zstd-1.5.2                 |       ha4553b6_0         488 KB
#     ------------------------------------------------------------
#                                            Total:        96.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h7b6447c_0
#   cairo              pkgs/main/linux-64::cairo-1.16.0-hb05425b_3
#   expat              pkgs/main/linux-64::expat-2.4.9-h6a678d5_0
#   ffmpeg             pkgs/main/linux-64::ffmpeg-4.0-hcdf2ecd_0
#   fontconfig         pkgs/main/linux-64::fontconfig-2.14.1-h52c9d5c_1
#   freeglut           pkgs/main/linux-64::freeglut-3.0.0-hf484d3e_5
#   glib               pkgs/main/linux-64::glib-2.69.1-h4ff587b_1
#   graphite2          pkgs/main/linux-64::graphite2-1.3.14-h295c915_1
#   harfbuzz           pkgs/main/linux-64::harfbuzz-1.8.8-hffaf4a1_0
#   hdf5               pkgs/main/linux-64::hdf5-1.10.2-hba1933b_1
#   jasper             pkgs/main/linux-64::jasper-2.0.14-hd8c5072_2
#   jpeg               pkgs/main/linux-64::jpeg-9e-h5eee18b_1
#   lerc               pkgs/main/linux-64::lerc-3.0-h295c915_0
#   libdeflate         pkgs/main/linux-64::libdeflate-1.17-h5eee18b_0
#   libgfortran-ng     pkgs/main/linux-64::libgfortran-ng-7.5.0-ha8ba4b0_17
#   libgfortran4       pkgs/main/linux-64::libgfortran4-7.5.0-ha8ba4b0_17
#   libglu             pkgs/main/linux-64::libglu-9.0.0-hf484d3e_1
#   libopencv          pkgs/main/linux-64::libopencv-3.4.2-hb342d67_1
#   libopus            pkgs/main/linux-64::libopus-1.3.1-h7b6447c_0
#   libtiff            pkgs/main/linux-64::libtiff-4.5.0-h6a678d5_2
#   libuuid            pkgs/main/linux-64::libuuid-1.41.5-h5eee18b_0
#   libvpx             pkgs/main/linux-64::libvpx-1.7.0-h439df22_0
#   libwebp-base       pkgs/main/linux-64::libwebp-base-1.2.4-h5eee18b_1
#   libxcb             pkgs/main/linux-64::libxcb-1.15-h7f8727e_0
#   libxml2            pkgs/main/linux-64::libxml2-2.9.14-h74e7548_0
#   lz4-c              pkgs/main/linux-64::lz4-c-1.9.4-h6a678d5_0
#   opencv             pkgs/main/linux-64::opencv-3.4.2-py37h6fd60c2_1
#   pcre               pkgs/main/linux-64::pcre-8.45-h295c915_0
#   pixman             pkgs/main/linux-64::pixman-0.40.0-h7f8727e_1
#   py-opencv          pkgs/main/linux-64::py-opencv-3.4.2-py37hb342d67_1
#   zstd               pkgs/main/linux-64::zstd-1.5.2-ha4553b6_0
#
# The following packages will be UPDATED:
#
#   openssl               anaconda::openssl-1.1.1s-h7f8727e_0 --> pkgs/main::openssl-1.1.1t-h7f8727e_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   icu                      conda-forge::icu-67.1-he1b5a44_0 --> pkgs/main::icu-58.2-he6710b0_3
#   matplotlib-base    conda-forge::matplotlib-base-3.2.2-py~ --> pkgs/main::matplotlib-base-3.2.2-py37hef1b27d_0
#
#
#
# Downloading and Extracting Packages
# libxcb-1.15          | 505 KB    |                                       |   0%
# cairo-1.16.0         | 1.2 MB    |                                       |   0%
#
# graphite2-1.3.14     | 97 KB     |                                       |   0%
#
#
# libwebp-base-1.2.4   | 376 KB    |                                       |   0%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    |                                       |   0%
#
#
#
#
# glib-2.69.1          | 1.7 MB    |                                       |   0%
#
#
#
#
#
# libgfortran-ng-7.5.0 | 22 KB     |                                       |   0%
#
#
#
#
#
#
# hdf5-1.10.2          | 3.8 MB    |                                       |   0%
#
#
#
#
#
#
#
# pixman-0.40.0        | 373 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# harfbuzz-1.8.8       | 507 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# py-opencv-3.4.2      | 1.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# expat-2.4.9          | 156 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libglu-9.0.0         | 271 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.7.0         | 1.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.17      | 69 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lerc-3.0             | 196 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jasper-2.0.14        | 736 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.1    | 281 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 207 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# opencv-3.4.2         | 11 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 262 KB    |                                       |   0%
#  ... (more hidden) ...
#
#
# libwebp-base-1.2.4   | 376 KB    | #5                                    |   4%
# cairo-1.16.0         | 1.2 MB    | 4                                     |   1%
#
# libxcb-1.15          | 505 KB    | #1                                    |   3%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | 1                                     |   0%
# cairo-1.16.0         | 1.2 MB    | ###9                                  |  11%
#
#
# libwebp-base-1.2.4   | 376 KB    | ####################4                 |  55%
#
# graphite2-1.3.14     | 97 KB     | ##################################### | 100%
#
# graphite2-1.3.14     | 97 KB     | ##################################### | 100%
#
#
#
#
# libxcb-1.15          | 505 KB    | #########3                            |  25%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | 7                                     |   2%
# cairo-1.16.0         | 1.2 MB    | #########3                            |  25%
#
#
# libwebp-base-1.2.4   | 376 KB    | ##################################### | 100%
#
#
# libwebp-base-1.2.4   | 376 KB    | ##################################### | 100%
#
#
#
#
# glib-2.69.1          | 1.7 MB    | ###3                                  |   9%
#
#
#
#
#
# libxcb-1.15          | 505 KB    | #####################                 |  57%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | #5                                    |   4%
#
#
#
#
#
# libgfortran-ng-7.5.0 | 22 KB     | ##################################### | 100%
# libxcb-1.15          | 505 KB    | ################################7     |  89%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ##3                                   |   6%
#
#
#
#
#
#
# hdf5-1.10.2          | 3.8 MB    | 1                                     |   0%
# cairo-1.16.0         | 1.2 MB    | #####################1                |  57%
#
#
#
#
# glib-2.69.1          | 1.7 MB    | #######9                              |  22%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ###                                   |   8%
#
#
#
#
#
#
# libxcb-1.15          | 505 KB    | ##################################### | 100%
# cairo-1.16.0         | 1.2 MB    | ###########################           |  73%
#
#
#
#
# glib-2.69.1          | 1.7 MB    | ##########6                           |  29%
#
#
#
#
#
#
#
# pixman-0.40.0        | 373 KB    | #5                                    |   4%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ###6                                  |  10%
#
#
#
#
#
#
# hdf5-1.10.2          | 3.8 MB    | ###3                                  |   9%
# cairo-1.16.0         | 1.2 MB    | ###############################9      |  86%
#
#
#
#
#
#
#
# pixman-0.40.0        | 373 KB    | ##############2                       |  39%
#
#
#
#
# glib-2.69.1          | 1.7 MB    | #############3                        |  36%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ####2                                 |  12%
#
#
#
#
#
#
# hdf5-1.10.2          | 3.8 MB    | #####1                                |  14%
#
#
#
#
#
#
#
# pixman-0.40.0        | 373 KB    | #################################3    |  90%
#
#
#
#
# glib-2.69.1          | 1.7 MB    | ################9                     |  46%
# cairo-1.16.0         | 1.2 MB    | ##################################### | 100%
# cairo-1.16.0         | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# harfbuzz-1.8.8       | 507 KB    | #1                                    |   3%
#
#
#
#
#
#
#
# pixman-0.40.0        | 373 KB    | ##################################### | 100%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ####9                                 |  13%
#
#
#
#
#
#
# hdf5-1.10.2          | 3.8 MB    | #######7                              |  21%
#
#
#
#
# glib-2.69.1          | 1.7 MB    | ####################6                 |  56%
#
#
#
#
#
#
#
#
# harfbuzz-1.8.8       | 507 KB    | ###################8                  |  54%
#
#
#
#
#
#
#
#
#
# py-opencv-3.4.2      | 1.0 MB    | 5                                     |   2%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | #####8                                |  16%
#
#
#
#
#
#
# hdf5-1.10.2          | 3.8 MB    | #########5                            |  26%
#
#
#
#
#
#
#
#
#
# py-opencv-3.4.2      | 1.0 MB    | #####                                 |  14%
#
#
#
#
#
#
#
#
# harfbuzz-1.8.8       | 507 KB    | ##############################3       |  82%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ######5                               |  18%
#
#
#
#
#
#
# hdf5-1.10.2          | 3.8 MB    | ###########2                          |  30%
#
#
#
#
# glib-2.69.1          | 1.7 MB    | #######################6              |  64%
#
#
#
#
#
#
#
#
# harfbuzz-1.8.8       | 507 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# py-opencv-3.4.2      | 1.0 MB    | ##########6                           |  29%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | #######3                              |  20%
#
#
#
#
#
#
# hdf5-1.10.2          | 3.8 MB    | #############3                        |  36%
#
#
#
#
# glib-2.69.1          | 1.7 MB    | #############################3        |  79%
#
#
#
#
#
#
#
#
#
#
# expat-2.4.9          | 156 KB    | ###7                                  |  10%
#
#
#
#
#
#
#
#
#
#
# expat-2.4.9          | 156 KB    | #######5                              |  20%
#
#
#
#
#
#
#
#
#
# py-opencv-3.4.2      | 1.0 MB    | ##############                        |  38%
#
#
#
#
#
#
#
#
#
#
# expat-2.4.9          | 156 KB    | ##################################### | 100%
#
#
#
#
#
#
# hdf5-1.10.2          | 3.8 MB    | ###############1                      |  41%
#
#
#
#
# glib-2.69.1          | 1.7 MB    | ################################9     |  89%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | #######9                              |  21%
#
#
#
#
#
#
#
#
#
# py-opencv-3.4.2      | 1.0 MB    | #######################               |  62%
#
#
#
#
#
#
#
#
#
#
#
# libglu-9.0.0         | 271 KB    | ##1                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
# libglu-9.0.0         | 271 KB    | ########7                             |  24%
#
#
#
#
#
#
# hdf5-1.10.2          | 3.8 MB    | ##################7                   |  51%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | #########5                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.7.0         | 1.2 MB    | 4                                     |   1%
#
#
#
#
#
#
#
#
#
# py-opencv-3.4.2      | 1.0 MB    | ############################1         |  76%
#
#
#
#
#
#
#
#
#
#
#
# libglu-9.0.0         | 271 KB    | ##################################### | 100%
#
#
#
#
#
#
# hdf5-1.10.2          | 3.8 MB    | ########################3             |  66%
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.7.0         | 1.2 MB    | ############5                         |  34%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ###########6                          |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.17      | 69 KB     | ########5                             |  23%
#
#
#
#
#
#
#
#
#
# py-opencv-3.4.2      | 1.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# py-opencv-3.4.2      | 1.0 MB    | ##################################### | 100%
# ffmpeg-4.0           | 53.3 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.17      | 69 KB     | ##################################### | 100%
#
#
#
#
# glib-2.69.1          | 1.7 MB    | ##################################### | 100%
#
#
#
#
# glib-2.69.1          | 1.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | 1                                     |   0%
#
#
#
#
#
#
# hdf5-1.10.2          | 3.8 MB    | ##########################9           |  73%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ############5                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.7.0         | 1.2 MB    | ###################                   |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lerc-3.0             | 196 KB    | ###                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | 2                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lerc-3.0             | 196 KB    | ##############################2       |  82%
#
#
#
#
#
#
# hdf5-1.10.2          | 3.8 MB    | #############################4        |  79%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | #############4                        |  36%
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.7.0         | 1.2 MB    | ########################5             |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lerc-3.0             | 196 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | 3                                     |   1%
#
#
#
#
#
#
# hdf5-1.10.2          | 3.8 MB    | ###############################6      |  86%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ##############2                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.7.0         | 1.2 MB    | #############################6        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jasper-2.0.14        | 736 KB    | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | 5                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jasper-2.0.14        | 736 KB    | #######2                              |  20%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ###############                       |  41%
#
#
#
#
#
#
# hdf5-1.10.2          | 3.8 MB    | #################################7    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.7.0         | 1.2 MB    | ##################################3   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jasper-2.0.14        | 736 KB    | ############8                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | 6                                     |   2%
#
#
#
#
#
#
# hdf5-1.10.2          | 3.8 MB    | ###################################7  |  97%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ###############7                      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.7.0         | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jasper-2.0.14        | 736 KB    | #####################7                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.1    | 281 KB    | ##1                                   |   6%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ################6                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 207 KB    | ##8                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jasper-2.0.14        | 736 KB    | #############################7        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | 9                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.1    | 281 KB    | ##################9                   |  51%
#
#
#
#
#
#
# hdf5-1.10.2          | 3.8 MB    | ##################################### | 100%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | #################4                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 207 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre-8.45            | 207 KB    | ##################################### | 100%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ##################4                   |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 262 KB    | ##2                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jasper-2.0.14        | 736 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jasper-2.0.14        | 736 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.1    | 281 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# opencv-3.4.2         | 11 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.1    | 281 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# opencv-3.4.2         | 11 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #3                                    |   4%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ###################3                  |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 262 KB    | ###########################1          |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 262 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | 7                                     |   2%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ####################1                 |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #6                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #                                     |   3%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | #####################                 |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #7                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #3                                    |   4%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | #####################9                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #9                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #6                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #9                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ##1                                   |   6%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | #######################3              |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ##2                                   |   6%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ########################1             |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ##2                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ###1                                  |   9%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ##########################1           |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ##7                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ###5                                  |  10%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ###########################1          |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ##9                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ###9                                  |  11%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ############################1         |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ###1                                  |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ####3                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ###3                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ####7                                 |  13%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | #############################8        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #####                                 |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ###5                                  |  10%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ##############################9       |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #####4                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ###7                                  |  10%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ###############################9      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #####8                                |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ###9                                  |  11%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ################################9     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ######2                               |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ####                                  |  11%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | #################################9    |  92%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ##################################9   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ####2                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ######6                               |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ####4                                 |  12%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ####################################  |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #######1                              |  19%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #######5                              |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ####6                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ####8                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ########                              |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ########5                             |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #####                                 |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #########                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #####3                                |  14%
#
#
#
# matplotlib-base-3.2. | 5.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #####5                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #########5                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #####7                                |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ##########1                           |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ######                                |  16%
# libopencv-3.4.2      | 21.8 MB   | ##########5                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ######2                               |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ###########                           |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ###########5                          |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ######4                               |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ############                          |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ######8                               |  19%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ############6                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #######1                              |  19%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #############1                        |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #######4                              |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #############6                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #######6                              |  21%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ##############1                       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #######9                              |  21%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ##############5                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ########1                             |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ###############                       |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ########3                             |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ###############5                      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ########6                             |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ################                      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ########8                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ################5                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #########1                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #################                     |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #########3                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #################6                    |  48%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #########6                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ##################1                   |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #########9                            |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ##################7                   |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ##########1                           |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ###################2                  |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ##########4                           |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ###################7                  |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ##########6                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ####################2                 |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ##########9                           |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ####################7                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ###########1                          |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #####################2                |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ###########4                          |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #####################7                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ###########6                          |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ######################2               |  60%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ###########9                          |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ######################7               |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ############1                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ############3                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #######################2              |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ############6                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #######################7              |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ############9                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ########################2             |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #############1                        |  36%
# libopencv-3.4.2      | 21.8 MB   | ########################7             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #############4                        |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #########################2            |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #############6                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #########################7            |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ##########################2           |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #############9                        |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ##########################7           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ##############1                       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ###########################3          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ##############4                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ##############6                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ###########################8          |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ############################3         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ##############8                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ############################8         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ###############1                      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ###############3                      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #############################3        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ###############5                      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #############################8        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ###############8                      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ##############################3       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ################                      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ##############################8       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ################2                     |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ###############################3      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ################5                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ###############################8      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ################7                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ################################3     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ################9                     |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ################################9     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #################2                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #################################4    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #################4                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | #################################9    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #################7                    |  48%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ##################################4   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #################9                    |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ##################################9   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ##################1                   |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ###################################4  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ##################4                   |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ###################################9  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ##################6                   |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ####################################3 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ###################                   |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ###################4                  |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ###################7                  |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ####################                  |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ####################3                 |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ####################7                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #####################2                |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopencv-3.4.2      | 21.8 MB   | ##################################### | 100%
# ffmpeg-4.0           | 53.3 MB   | #####################6                |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ######################                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ######################6               |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #######################1              |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #######################6              |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ########################              |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ########################5             |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ########################9             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #########################3            |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #########################8            |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ##########################2           |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ##########################6           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ###########################           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ###########################4          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ###########################9          |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ############################3         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ############################7         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #############################3        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #############################8        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ##############################2       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ##############################6       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ###############################       |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ###############################4      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ################################      |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ################################4     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ################################9     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #################################3    |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | #################################8    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ##################################2   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ##################################7   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ###################################2  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ###################################7  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ####################################1 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ####################################6 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.0           | 53.3 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda install -y -c anaconda pillow
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/yanboyang713/.conda/envs/anomaly
#
#   added / updated specs:
#     - pillow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     giflib-5.2.1               |       h5eee18b_1          72 KB  anaconda
#     lcms2-2.12                 |       h3be6417_0         396 KB  anaconda
#     libwebp-1.2.4              |       h11a3e52_0          85 KB  anaconda
#     pillow-9.3.0               |   py37h6a678d5_2         724 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         1.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   giflib             anaconda/linux-64::giflib-5.2.1-h5eee18b_1
#   lcms2              anaconda/linux-64::lcms2-2.12-h3be6417_0
#   libwebp            anaconda/linux-64::libwebp-1.2.4-h11a3e52_0
#   pillow             anaconda/linux-64::pillow-9.3.0-py37h6a678d5_2
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   openssl              pkgs/main::openssl-1.1.1t-h7f8727e_0 --> anaconda::openssl-1.1.1s-h7f8727e_0
#
#
#
# Downloading and Extracting Packages
# giflib-5.2.1         | 72 KB     |                                       |   0%
# lcms2-2.12           | 396 KB    |                                       |   0%
#
# libwebp-1.2.4        | 85 KB     |                                       |   0%
#
#
# pillow-9.3.0         | 724 KB    |                                       |   0%
#
#
# pillow-9.3.0         | 724 KB    | 8                                     |   2%
#
#
# pillow-9.3.0         | 724 KB    | #################1                    |  46%
#
# libwebp-1.2.4        | 85 KB     | ######9                               |  19%
#
# libwebp-1.2.4        | 85 KB     | ##################################### | 100%
# giflib-5.2.1         | 72 KB     | ##################################### | 100%
# lcms2-2.12           | 396 KB    | ###############################3      |  85%
#
#
# pillow-9.3.0         | 724 KB    | ##################################### | 100%
#
#
# pillow-9.3.0         | 724 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda install -y -c anaconda psycopg2
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/yanboyang713/.conda/envs/anomaly
#
#   added / updated specs:
#     - psycopg2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     krb5-1.19.4                |       h568e23c_0         1.4 MB  anaconda
#     libedit-3.1.20221030       |       h5eee18b_0         191 KB  anaconda
#     libpq-12.9                 |       h16c4e8d_3         2.8 MB  anaconda
#     psycopg2-2.9.3             |   py37h37d81fd_0         179 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         4.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   krb5               anaconda/linux-64::krb5-1.19.4-h568e23c_0
#   libedit            anaconda/linux-64::libedit-3.1.20221030-h5eee18b_0
#   libpq              anaconda/linux-64::libpq-12.9-h16c4e8d_3
#   psycopg2           anaconda/linux-64::psycopg2-2.9.3-py37h37d81fd_0
#
#
#
# Downloading and Extracting Packages
# psycopg2-2.9.3       | 179 KB    |                                       |   0%
# krb5-1.19.4          | 1.4 MB    |                                       |   0%
#
# libedit-3.1.20221030 | 191 KB    |                                       |   0%
#
#
# libpq-12.9           | 2.8 MB    |                                       |   0%
# psycopg2-2.9.3       | 179 KB    | ###2                                  |   9%
# psycopg2-2.9.3       | 179 KB    | ##################################### | 100%
# krb5-1.19.4          | 1.4 MB    | #################5                    |  47%
#
#
# libpq-12.9           | 2.8 MB    | 2                                     |   1%
#
# libedit-3.1.20221030 | 191 KB    | ###                                   |   8%
#
#
# libpq-12.9           | 2.8 MB    | #4                                    |   4%
#
# libedit-3.1.20221030 | 191 KB    | ###############4                      |  42%
# krb5-1.19.4          | 1.4 MB    | ########################6             |  67%
#
#
# libpq-12.9           | 2.8 MB    | ##6                                   |   7%
#
#
# libpq-12.9           | 2.8 MB    | ######7                               |  18%
#
# libedit-3.1.20221030 | 191 KB    | ##################################### | 100%
#
# libedit-3.1.20221030 | 191 KB    | ##################################### | 100%
#
#
# libpq-12.9           | 2.8 MB    | ###########8                          |  32%
#
#
# libpq-12.9           | 2.8 MB    | #################8                    |  48%
# krb5-1.19.4          | 1.4 MB    | ##################################### | 100%
# krb5-1.19.4          | 1.4 MB    | ##################################### | 100%
#
#
# libpq-12.9           | 2.8 MB    | #######################7              |  64%
#
#
# libpq-12.9           | 2.8 MB    | #############################5        |  80%
#
#
# libpq-12.9           | 2.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# ## Database

# %% [markdown]
# ### Set Database parameters

# %%
param_dic = {
    "host"      : "localhost",
    "database"  : "anomalyprediction",
    "user"      : "postgres",
    "password"  : "password"
}

# %%
import psycopg2

# %%
def connect(params_dic):
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # connect to the PostgreSQL server
        print('Connecting to the PostgreSQL database...')
        conn = psycopg2.connect(**params_dic)
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        sys.exit(1) 
    print("Connection successful")
    return conn
conn = connect(param_dic)
# Out:
# Connecting to the PostgreSQL database...
# Connection successful

# %% [markdown]
# ## Data read and write function

# %%
import psycopg2.extras as extras
def execute_values(conn, df, table):
    """
    Using psycopg2.extras.execute_values() to insert the dataframe
    """
    # Create a list of tupples from the dataframe values
    tuples = [tuple(x) for x in df.to_numpy()]
    # Comma-separated dataframe columns
    cols = ','.join(df.columns.values.tolist())
    # SQL quert to execute
    query  = "INSERT INTO %s(%s) VALUES %%s" % (table, cols)
    cursor = conn.cursor()
    try:
        extras.execute_values(cursor, query, tuples)
        conn.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        conn.rollback()
        cursor.close()
        return 1
    print("execute_values() done")
    cursor.close()

# %%
def postgresql_to_dataframe(conn, select_query, column_names):
    """
    Tranform a SELECT query into a pandas dataframe
    """
    cursor = conn.cursor()
    try:
        cursor.execute(select_query)
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        cursor.close()
        return 1
    
    # Naturally we get a list of tupples
    tupples = cursor.fetchall()
    cursor.close()
    
    # We just need to turn it into a pandas dataframe
    df = pd.DataFrame(tupples, columns=column_names)
    return df

# %% [markdown]
# ## Basic Analysis

# %%
import pandas as pd

# %% [markdown]
# ### Check how many runs

# %% [markdown]
# ```sql
# SELECT COUNT(DISTINCT runid) AS unique_count, runid
# FROM runrecord
# GROUP BY runid;
# ```

# %%
# Connect to the database
conn = connect(param_dic)
column_names = ["COUNT", "runid"]
# Execute the "SELECT *" query
df = postgresql_to_dataframe(conn, "SELECT COUNT(DISTINCT runid) AS unique_count, runid FROM runrecord GROUP BY runid;", column_names)

df
# Out:
# Connecting to the PostgreSQL database...
# Connection successful
#     COUNT                                              runid
# 0       1   0863e1b4222e208299e73cafaaf5688a94e737a278ea4...
# 1       1   0997b20b9949ea6d971ab04ee8d8564a591d83ba8e92f...
# 2       1   0c85d4d242771daf31a92904951188d61acf18e8c2a02...
# 3       1   0d1e789fa90d582d91adfa855acf597df3d17fb7082de...
# 4       1   13063a390fb477a32a40cf94ef0cf6eaa73ff5a28173f...
# ..    ...                                                ...
# 77      1   ec6cb34096219704bf43f0417946a929c77463ef55d77...
# 78      1   f181df6f305cf98315069bdffbbfd81f5365541742659...
# 79      1   f8a06866447fa9e1b736c7e17b2c882af1b489c7ae438...
# 80      1   fb91e5677e438260c9fd7dbe6594ff6d572fb10674d11...
# 81      1   fe3491ab7ac805c140f7787c4ff397f8507950eb99ef1...
#
# [82 rows x 2 columns]

# %% [markdown]
# ### Number of RX packets with runid

# %% [markdown]
# #### Get DISTINCT(runid)

# %% [markdown]
# ```sql
# SELECT DISTINCT(runid)AS unique_count, runid
# FROM rxpacketinfo;
# ```

# %%
# Connect to the database
conn = connect(param_dic)
column_names = ["DISTINCT(runid)"]
# Execute the "SELECT *" query
df = postgresql_to_dataframe(conn, "SELECT DISTINCT(runid) AS unique_count, runid FROM rxpacketinfo;", column_names)

df
# Out:
# Connecting to the PostgreSQL database...
# Connection successful
#                                      DISTINCT(runid)
# 0   5961dbf2e92852ac8b1068090d030a8a4eaaf8c71f8f9...

# %%
runidList = df['DISTINCT(runid)'].tolist()

# %%
print (runidList[0])
# Out:
#  5961dbf2e92852ac8b1068090d030a8a4eaaf8c71f8f935e7603f6c1cca18b18

# %% [markdown]
# #### number of unique packets

# %% [markdown]
# ```sql
# SELECT COUNT(DISTINCT(packetuid))AS unique_count
# FROM rxpacketinfo
# WHERE runid LIKE '%5961dbf2e92852ac8b1068090d030a8a4eaaf8c71f8f935e7603f6c1cca18b18%';
# ```

# %%
# Connect to the database
conn = connect(param_dic)
column_names = ["numRXpoackets"]
# Execute the "SELECT *" query
df = postgresql_to_dataframe(conn, "SELECT COUNT(DISTINCT(packetuid))AS unique_count FROM rxpacketinfo WHERE runid LIKE '%5961dbf2e92852ac8b1068090d030a8a4eaaf8c71f8f935e7603f6c1cca18b18%';", column_names)

df
# Out:
# Connecting to the PostgreSQL database...
# Connection successful
#    numRXpoackets
# 0           4290

# %% [markdown]
# #### number of packets

# %% [markdown]
# ```sql
# SELECT COUNT(packetuid)AS unique_count
# FROM rxpacketinfo
# WHERE runid LIKE '%5961dbf2e92852ac8b1068090d030a8a4eaaf8c71f8f935e7603f6c1cca18b18%';
# ```

# %%
# Connect to the database
conn = connect(param_dic)
column_names = ["numRXpoackets"]
# Execute the "SELECT *" query
df = postgresql_to_dataframe(conn, "SELECT COUNT(packetuid)AS unique_count FROM rxpacketinfo WHERE runid LIKE '%5961dbf2e92852ac8b1068090d030a8a4eaaf8c71f8f935e7603f6c1cca18b18%';", column_names)

df
# Out:
# Connecting to the PostgreSQL database...
# Connection successful
#    numRXpoackets
# 0          14349

# %% [markdown]
# #### Number of RX packets for  Ground-Station

# %%
```sql
SELECT COUNT(packetuid)
FROM rxpacketinfo
WHERE nodename LIKE '%Ground-Station%'
AND runid LIKE '%5961dbf2e92852ac8b1068090d030a8a4eaaf8c71f8f935e7603f6c1cca18b18%';
```

# %%
# Connect to the database
conn = connect(param_dic)
column_names = ["numRXoackets"]
# Execute the "SELECT *" query
df = postgresql_to_dataframe(conn, "SELECT COUNT(packetuid) FROM rxpacketinfo WHERE nodename LIKE '%Ground-Station%' AND runid LIKE '%5961dbf2e92852ac8b1068090d030a8a4eaaf8c71f8f935e7603f6c1cca18b18%';", column_names)

df
# Out:
# Connecting to the PostgreSQL database...
# Connection successful
#    numRXoackets
# 0          4282

# %% [markdown]
# #### Number of RX packets for  UAV-0

# %% [markdown]
# ```sql
# SELECT COUNT(packetuid)
# FROM rxpacketinfo
# WHERE nodename LIKE '%UAV-0%'
# AND runid LIKE '%5961dbf2e92852ac8b1068090d030a8a4eaaf8c71f8f935e7603f6c1cca18b18%';
# ```

# %%
# Connect to the database
conn = connect(param_dic)
column_names = ["numRXoackets"]
# Execute the "SELECT *" query
df = postgresql_to_dataframe(conn, "SELECT COUNT(packetuid) FROM rxpacketinfo WHERE nodename LIKE '%UAV-0%' AND runid LIKE '%5961dbf2e92852ac8b1068090d030a8a4eaaf8c71f8f935e7603f6c1cca18b18%';", column_names)

df
# Out:
# Connecting to the PostgreSQL database...
# Connection successful
#    numRXoackets
# 0          3061

# %% [markdown]
# #### Number of RX packets for  UAV-1

# %% [markdown]
# ```sql
# SELECT COUNT(packetuid)
# FROM rxpacketinfo
# WHERE nodename LIKE '%UAV-1%'
# AND runid LIKE '%5961dbf2e92852ac8b1068090d030a8a4eaaf8c71f8f935e7603f6c1cca18b18%';
# ```

# %%
# Connect to the database
conn = connect(param_dic)
column_names = ["numRXoackets"]
# Execute the "SELECT *" query
df = postgresql_to_dataframe(conn, "SELECT COUNT(packetuid) FROM rxpacketinfo WHERE nodename LIKE '%UAV-1%' AND runid LIKE '%5961dbf2e92852ac8b1068090d030a8a4eaaf8c71f8f935e7603f6c1cca18b18%';", column_names)

df
# Out:
# Connecting to the PostgreSQL database...
# Connection successful
#    numRXoackets
# 0          3062

# %% [markdown]
# #### Number of RX packets for  UAV-2

# %% [markdown]
# ```sql
# SELECT COUNT(packetuid)
# FROM rxpacketinfo
# WHERE nodename LIKE '%UAV-2%'
# AND runid LIKE '%5961dbf2e92852ac8b1068090d030a8a4eaaf8c71f8f935e7603f6c1cca18b18%';
# ```

# %%
# Connect to the database
conn = connect(param_dic)
column_names = ["numRXoackets"]
# Execute the "SELECT *" query
df = postgresql_to_dataframe(conn, "SELECT COUNT(packetuid) FROM rxpacketinfo WHERE nodename LIKE '%UAV-2%' AND runid LIKE '%5961dbf2e92852ac8b1068090d030a8a4eaaf8c71f8f935e7603f6c1cca18b18%';", column_names)

df
# Out:
# Connecting to the PostgreSQL database...
# Connection successful
#    numRXoackets
# 0          3944

# %%
print

# %% [markdown]
# ```sql
# SELECT COUNT(runid)
# FROM rxpacketinfo;
# ```

# %%
# Connect to the database
conn = connect(param_dic)
column_names = ["COUNT(runid)"]
# Execute the "SELECT *" query
df = postgresql_to_dataframe(conn, "SELECT COUNT(runid) FROM rxpacketinfo;", column_names)

df
# Out:
# Connecting to the PostgreSQL database...
# Connection successful
#    COUNT(runid)
# 0         14349

# %% [markdown]
# ## Connect close

# %%
conn.close()
